# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhusudan3223/Sales-Customer-Insights-Analysis/blob/main/Sales_%26_Customer_Insights_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📊 Sales & Customer Insights Analysis – Superstore Dataset
#
# ### 📝 Project Summary
#
# This project explores and visualizes the Superstore Sales dataset to uncover meaningful patterns and insights across regions, customer segments, categories, and shipping modes.
#
# ---
#
# ### ✅ Objective
#
# - Identify top-performing regions, products, and customer segments
# - Analyze sales and profit distribution across key dimensions
# - Evaluate the impact of discounts on profitability
# - Enable data-driven business decisions through visual insights
#
# ---
#
# ### 🔍 Key Steps & Insights
#
# - **Data Cleaning**: Removed nulls, converted date columns, verified data types
# - **Region-wise Analysis**: West leads in overall sales
# - **Top Customers**: Identified top 10 customers by sales
# - **Category/Sub-Category**: Technology and Phones dominate sales
# - **Shipping Mode**: Standard Class most used, Second Class has high revenue
# - **Segment Analysis**: Consumer segment drives both sales and profit
# - **Monthly Trends**: Sales show seasonality and spikes during key months
# - **Correlation Matrix**: Discounts negatively impact profits
# - **State-Level Insight**: Top 10 states contribute majority of revenue
#
# ---
#
# ### 📊 Visualizations Used
#
# - Bar plots for Sales & Profit by Region, Segment, Ship Mode
# - Pie chart for Category sales share
# - Line plots for monthly trend analysis
# - Heatmap to show correlation between metrics
# - Scatter plot (Discount vs Profit by Category)
#
# ---
#
# ### 💡 Business Insights
#
# - 🚫 Deep discounts reduce profit significantly
# - 🧑‍🤝‍🧑 A few customers generate a large portion of revenue
# - 🚚 Shipping strategy can be optimized for better profitability
# - 📍 Certain states & sub-categories outperform and should be prioritized
#
# ---
#
# ### 📁 Output
#
# - Cleaned dataset saved as `cleaned_superstore.csv` for further use (e.g., Tableau/Power BI)
#
# ---
#
# ### 🛠️ Tools & Libraries
#
# - Python, Pandas, NumPy, Matplotlib, Seaborn

# %% [markdown]
# ### 📦 Extracting Superstore Dataset from ZIP File
#
# This section handles the extraction of the "Sample - Superstore.csv" dataset from a ZIP file using Python's `zipfile` module and prepares the data directory for analysis.

# %%
import zipfile
import os

# Your uploaded ZIP file name
zip_path = "/content/Sample - Superstore.csv.zip"

# Create a folder to extract files
extract_folder = "/content/superstore_data"

# Extract ZIP contents
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

# List extracted files
os.listdir(extract_folder)
# Out:
# ['Sample - Superstore.csv']

# %% [markdown]
# ### 📄 Loading Superstore Dataset with Proper Encoding
#
# This section loads the extracted `Sample - Superstore.csv` file using `pandas`, ensuring correct encoding (`ISO-8859-1`) to handle special characters. It then displays the first 5 rows of the dataset for initial inspection.

# %%
import pandas as pd

# Load CSV with correct encoding
df = pd.read_csv("/content/superstore_data/Sample - Superstore.csv", encoding='ISO-8859-1')

# Preview first 5 rows
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### 🔍 Dataset Structure and Data Types
#
# This step uses `df.info()` to check the basic structure of the Superstore dataset, including:
#
# - Total number of entries (rows)
# - Column names
# - Non-null counts
# - Data types of each column
#
# This helps in understanding memory usage and identifying any missing values or incorrect data types.

# %%
# Basic structure and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ### 🧹 Missing Values Check
#
# This step checks for missing or null values in each column of the dataset using:

# %%
# Check for missing/null values
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ### 🔍 Duplicate Records Check
#
# This line checks for duplicate rows in the dataset:

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 📊 Descriptive Statistics Summary
#
# The following command provides basic statistical insights into the numerical columns of the dataset:

# %%
# Show basic stats
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# ### 🧹 Removing Duplicate Records
#
# To ensure data quality, we remove any duplicate rows from the dataset:

# %%
# Remove duplicate rows
df = df.drop_duplicates()
print("Duplicates removed. Current shape:", df.shape)
# Out:
# Duplicates removed. Current shape: (9994, 21)

# %% [markdown]
# ### 🔍 Confirming Data Types After Cleaning
#
# After cleaning the dataset (e.g., removing duplicates), it's important to verify the data types of each column:

# %%
# Confirm data types after cleaning
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %% [markdown]
# ### 🧼 Previewing Cleaned Data
#
# Display the first 5 rows of the cleaned dataset to ensure it looks correct and is ready for analysis:

# %%
# Preview cleaned data
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### 💰 Key Business Metrics Summary
#
# Prints the total sales, total profit, and total quantity sold across the dataset to get a high-level view of performance:

# %%
print("Total Sales: $", round(df['Sales'].sum(), 2))
print("Total Profit: $", round(df['Profit'].sum(), 2))
print("Total Quantity Sold:", df['Quantity'].sum())
# Out:
# Total Sales: $ 2297200.86
# Total Profit: $ 286397.02
# Total Quantity Sold: 37873

# %% [markdown]
# ### 🌍 Sales and Profit by Region
#
# Groups the dataset by **Region** and calculates the **total Sales and Profit** for each region. The results are sorted in descending order of sales to identify the highest-performing regions.

# %%
region_sales = df.groupby('Region')[['Sales', 'Profit']].sum().sort_values(by='Sales', ascending=False)
region_sales
# Out:
#                Sales       Profit
# Region
# West     725457.8245  108418.4489
# East     678781.2400   91522.7800
# Central  501239.8908   39706.3625
# South    391721.9050   46749.4303

# %% [markdown]
# ### 🏆 Top 10 Customers by Sales
#
# Identifies the top 10 customers based on their **total sales contribution**. This helps in recognizing the most valuable clients for the business.

# %%
top_customers = df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)
top_customers
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %% [markdown]
# ### 📊 Sales & Profit by Category and Sub-Category
#
# This analysis groups the data by **Category** and **Sub-Category**, calculating the total **Sales** and **Profit** for each combination. The top 10 entries (by sales) are shown to highlight the most revenue-generating product segments.

# %%
category_sales = df.groupby(['Category', 'Sub-Category'])[['Sales', 'Profit']].sum().sort_values(by='Sales', ascending=False)
category_sales.head(10)
# Out:
#                                     Sales      Profit
# Category        Sub-Category
# Technology      Phones        330007.0540  44515.7306
# Furniture       Chairs        328449.1030  26590.1663
# Office Supplies Storage       223843.6080  21278.8264
# Furniture       Tables        206965.5320 -17725.4811
# Office Supplies Binders       203412.7330  30221.7633
# Technology      Machines      189238.6310   3384.7569
#                 Accessories   167380.3180  41936.6357
#                 Copiers       149528.0300  55617.8249
# Furniture       Bookcases     114879.9963  -3472.5560
# Office Supplies Appliances    107532.1610  18138.0054

# %% [markdown]
# ### 📈 Monthly Sales Trend Analysis
#
# This section converts the `Order Date` column to datetime format and then groups sales data by **month** to analyze trends over time. The resulting line chart visualizes how sales fluctuate across months.

# %%
# Convert to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Monthly sales
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum()
monthly_sales.plot(kind='line', figsize=(10,5), title='Monthly Sales Trend')
# Out:
# <Axes: title={'center': 'Monthly Sales Trend'}, xlabel='Order Date'>

# %% [markdown]
# ### 🎨 Setting Up Visualization Environment
#
# Before plotting any charts, we import the required

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")

# %% [markdown]
# ### 📊 Sales by Region (Horizontal Bar Chart)
#
# This visualization shows the total sales across different regions using a horizontal bar chart. The data is grouped by `Region`

# %%
region_sales = df.groupby('Region')['Sales'].sum().sort_values()
region_sales.plot(kind='barh', color='skyblue', figsize=(8,5), title='Sales by Region')
plt.xlabel('Sales')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# ### 💰 Profit by Product Category (Bar Chart)
#
# This visualization displays the total profit generated by each product category. The chart helps in identifying which categories are more profitable based on the aggregated profit values.

# %%
category_profit = df.groupby('Category')['Profit'].sum()
category_profit.plot(kind='bar', color='lightgreen', figsize=(6,4), title='Profit by Category')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ### 📊 Top 10 Sub-Categories by Sales (Horizontal Bar Chart)
#
# This bar chart highlights the top 10 sub-categories with the highest total sales. It helps identify which product sub-categories are the most revenue-generating, offering key insights for inventory planning and sales strategies.

# %%
top_subcat = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=top_subcat.values, y=top_subcat.index, palette='mako')
plt.title('Top 10 Sub-Categories by Sales')
plt.xlabel('Sales')
plt.show()
# Out:
# /tmp/ipython-input-24-338338143.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_subcat.values, y=top_subcat.index, palette='mako')

# %% [markdown]
# ### 📈 Sales vs. Profit by Category (Scatter Plot)
#
# This scatter plot visualizes the relationship between sales and profit across different product categories. It helps in identifying high-sales but low-profit segments, or categories that consistently yield higher profitability.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Sales', y='Profit', hue='Category', data=df)
plt.title('Sales vs Profit by Category')
plt.show()

# %% [markdown]
# ### 🚚 Sales by Shipping Mode
#
# This horizontal bar chart shows total sales grouped by different shipping modes. It provides insights into which shipping options are most popular or contribute the most to revenue.

# %%
ship_sales = df.groupby('Ship Mode')['Sales'].sum().sort_values()
ship_sales.plot(kind='barh', color='orange', figsize=(7,4), title='Sales by Ship Mode')
plt.xlabel('Sales')
plt.ylabel('Ship Mode')
plt.show()

# %% [markdown]
# ### 🧑‍💼 Sales and Profit by Customer Segment
#
# This grouped bar chart displays the total Sales and Profit across different customer segments (Consumer, Corporate, Home Office). It highlights how each segment contributes to the overall business revenue and profitability.

# %%
segment_data = df.groupby('Segment')[['Sales', 'Profit']].sum().sort_values(by='Sales', ascending=False)
segment_data.plot(kind='bar', figsize=(7,5), color=['#007acc', '#00cc99'], title='Sales and Profit by Segment')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# ### 🗺️ Top 10 States by Sales
#
# This horizontal bar chart highlights the top 10 U.S. states with the highest total sales. It provides a quick snapshot of regional performance, helping identify key markets contributing the most to overall revenue.

# %%
top_states = df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=top_states.values, y=top_states.index, palette='coolwarm')
plt.title('Top 10 States by Sales')
plt.xlabel('Sales')
plt.show()
# Out:
# /tmp/ipython-input-28-3473317354.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_states.values, y=top_states.index, palette='coolwarm')

# %% [markdown]
# ### 📊 Correlation Matrix of Key Metrics
#
# The heatmap below visualizes the correlation between key numerical features: **Sales**, **Quantity**, **Discount**, and **Profit**

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[['Sales', 'Quantity', 'Discount', 'Profit']].corr(), annot=True, cmap='Blues')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### 💸 Discount vs Profit by Category
#
# This scatter plot illustrates the relationship between **Discount** and **Profit** across different product categories. Each point represents an order, colored by category.

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=df, x='Discount', y='Profit', hue='Category')
plt.title('Discount vs Profit by Category')
plt.show()

# %% [markdown]
# ### 🥧 Sales Share by Category
#
# This pie chart visualizes the proportion of total **Sales** contributed by each product **Category**. It highlights which segments dominate the sales distribution.

# %%
category_share = df.groupby('Category')['Sales'].sum()
category_share.plot(kind='pie', autopct='%1.1f%%', startangle=140, figsize=(6,6), title='Sales Share by Category')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### 💾 Saving the Cleaned Superstore Dataset
#
# After performing all data cleaning, transformation, and feature engineering steps, we save the final cleaned dataset for further analysis or dashboard development.

# %%
# Save cleaned dataset
df.to_csv("cleaned_superstore.csv", index=False)
